# %%
import pandas as pd 
import numpy as np
import plotly.express as px
import seaborn as sns
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder
from category_encoders import BinaryEncoder
from sklearn.preprocessing import StandardScaler, MinMaxScaler, RobustScaler
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR
from sklearn.ensemble import RandomForestRegressor, AdaBoostRegressor, GradientBoostingRegressor
from xgboost import XGBRegressor
from sklearn.model_selection import cross_validate, train_test_split
from sklearn.metrics import r2_score,mean_squared_error,make_scorer
from sklearn.feature_selection import SequentialFeatureSelector, SelectKBest, f_regression,RFE
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import GridSearchCV

# %%
df=pd.read_csv('black_friday.csv',index_col=[0])

# %% [markdown]
# # EDA

# %%
df.sample(20)
# Out:
#         Product_ID Gender    Age  Occupation City_Category  \
# User_ID
# 1004979  P00313142      M  36-45           2             B
# 1002436  P00127242      M  26-35           7             B
# 1002947  P00337942      F  26-35           0             A
# 1003724  P00113742      M  36-45           6             B
# 1000303  P00051442      M  26-35           7             C
# 1002659  P00202242      M  36-45          14             B
# 1002685  P00119742      M  46-50           7             C
# 1000839  P00127942      M  26-35           0             A
# 1002223  P00033042      M  26-35           2             B
# 1001451  P00044342      M  36-45          20             B
# 1001709  P00251942      M  26-35           0             C
# 1002237  P00153742      F  36-45           6             B
# 1002217  P00302842      M   0-17          10             C
# 1003032  P00329342      M  26-35           0             A
# 1000336  P00046742      M  18-25           0             C
# 1003974   P0096042      M  36-45           0             C
# 1004937  P00130642      M  36-45           0             C
# 1001088  P00088842      F   0-17          10             A
# 1005961  P00022442      F  46-50           0             A
# 1005682  P00278442      M  18-25           0             B
#
#         Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# User_ID
# 1004979                          1               1                   8
# 1002436                          2               0                   1
# 1002947                          1               1                   5
# 1003724                         4+               0                   5
# 1000303                          1               1                   8
# 1002659                         4+               1                  10
# 1002685                          2               1                   5
# 1000839                          2               0                   1
# 1002223                          0               1                   5
# 1001451                          0               0                   8
# 1001709                          1               1                   1
# 1002237                          1               0                   8
# 1002217                          0               0                   8
# 1003032                          1               1                   5
# 1000336                         4+               0                   1
# 1003974                          1               1                   3
# 1004937                          1               1                  11
# 1001088                          3               0                   8
# 1005961                          3               0                   8
# 1005682                          2               0                  11
#
#          Product_Category_2  Product_Category_3  Purchase
# User_ID
# 1004979                 NaN                 NaN      7944
# 1002436                16.0                 NaN     15255
# 1002947                 NaN                 NaN      5257
# 1003724                14.0                 NaN      8676
# 1000303                17.0                 NaN     10071
# 1002659                16.0                 NaN     19300
# 1002685                 8.0                12.0      8636
# 1000839                 2.0                 5.0     15297
# 1002223                14.0                 NaN      7172
# 1001451                 NaN                 NaN      9796
# 1001709                 2.0                 5.0     11433
# 1002237                 NaN                 NaN      6003
# 1002217                13.0                 NaN      9797
# 1003032                 NaN                 NaN      8604
# 1000336                 2.0                15.0     15692
# 1003974                 4.0                12.0      8344
# 1004937                16.0                 NaN      4501
# 1001088                 NaN                 NaN      7925
# 1005961                16.0                 NaN      8086
# 1005682                 NaN                 NaN      3031

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 550068 entries, 1000001 to 1006039
# Data columns (total 11 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   Product_ID                  550068 non-null  object
#  1   Gender                      550068 non-null  object
#  2   Age                         550068 non-null  object
#  3   Occupation                  550068 non-null  int64
#  4   City_Category               550068 non-null  object
#  5   Stay_In_Current_City_Years  550068 non-null  object
#  6   Marital_Status              550068 non-null  int64
#  7   Product_Category_1          550068 non-null  int64
#  8   Product_Category_2          376430 non-null  float64
#  9   Product_Category_3          166821 non-null  float64
#  10  Purchase                    550068 non-null  int64
# dtypes: float64(2), int64(4), object(5)
# memory usage: 50.4+ MB

# %%
df['Stay_In_Current_City_Years'].value_counts()
# Out:
# 1     193821
# 2     101838
# 3      95285
# 4+     84726
# 0      74398
# Name: Stay_In_Current_City_Years, dtype: int64

# %%
df['Product_ID'].unique()
# Out:
# array(['P00069042', 'P00248942', 'P00087842', ..., 'P00370293',
#        'P00371644', 'P00370853'], dtype=object)

# %%
df['Gender'].unique()
# Out:
# array(['F', 'M'], dtype=object)

# %%
df['Occupation'].unique()
# Out:
# array([10, 16, 15,  7, 20,  9,  1, 12, 17,  0,  3,  4, 11,  8, 19,  2, 18,
#         5, 14, 13,  6], dtype=int64)

# %%
df['City_Category'].unique()
# Out:
# array(['A', 'C', 'B'], dtype=object)

# %%
df['Marital_Status'].unique()
# Out:
# array([0, 1], dtype=int64)

# %%
df['Product_Category_1'].unique()
# Out:
# array([ 3,  1, 12,  8,  5,  4,  2,  6, 14, 11, 13, 15,  7, 16, 18, 10, 17,
#         9, 20, 19], dtype=int64)

# %%
df['Product_Category_2'].unique()
# Out:
# array([nan,  6., 14.,  2.,  8., 15., 16., 11.,  5.,  3.,  4., 12.,  9.,
#        10., 17., 13.,  7., 18.])

# %%
df['Product_Category_3'].unique()
# Out:
# array([nan, 14., 17.,  5.,  4., 16., 15.,  8.,  9., 13.,  6., 12.,  3.,
#        18., 11., 10.])

# %%
df['Purchase'].unique()
# Out:
# array([ 8370, 15200,  1422, ...,   135,   123,   613], dtype=int64)

# %% [markdown]
# # Cleaning Data:

# %% [markdown]
# ## Fix Product ID

# %%
df['Product_ID']=df['Product_ID'].apply(lambda x :  x[1:])

# %%
df['Product_ID']=pd.to_numeric(df['Product_ID'],errors='coerce')

# %%
df
# Out:
#          Product_ID Gender    Age  Occupation City_Category  \
# User_ID
# 1000001       69042      F   0-17          10             A
# 1000001      248942      F   0-17          10             A
# 1000001       87842      F   0-17          10             A
# 1000001       85442      F   0-17          10             A
# 1000002      285442      M    55+          16             C
# ...             ...    ...    ...         ...           ...
# 1006033      372445      M  51-55          13             B
# 1006035      375436      F  26-35           1             C
# 1006036      375436      F  26-35          15             B
# 1006038      375436      F    55+           1             C
# 1006039      371644      F  46-50           0             B
#
#         Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# User_ID
# 1000001                          2               0                   3
# 1000001                          2               0                   1
# 1000001                          2               0                  12
# 1000001                          2               0                  12
# 1000002                         4+               0                   8
# ...                            ...             ...                 ...
# 1006033                          1               1                  20
# 1006035                          3               0                  20
# 1006036                         4+               1                  20
# 1006038                          2               0                  20
# 1006039                         4+               1                  20
#
#          Product_Category_2  Product_Category_3  Purchase
# User_ID
# 1000001                 NaN                 NaN      8370
# 1000001                 6.0                14.0     15200
# 1000001                 NaN                 NaN      1422
# 1000001                14.0                 NaN      1057
# 1000002                 NaN                 NaN      7969
# ...                     ...                 ...       ...
# 1006033                 NaN                 NaN       368
# 1006035                 NaN                 NaN       371
# 1006036                 NaN                 NaN       137
# 1006038                 NaN                 NaN       365
# 1006039                 NaN                 NaN       490
#
# [550068 rows x 11 columns]

# %% [markdown]
# ## Fix stay in current city years

# %%
df['Stay_In_Current_City_Years'].replace('4+',4,inplace=True)

# %%
df['Stay_In_Current_City_Years'].value_counts()
# Out:
# 1    193821
# 2    101838
# 3     95285
# 4     84726
# 0     74398
# Name: Stay_In_Current_City_Years, dtype: int64

# %% [markdown]
# ## Fix Age

# %%
df['Age'].unique()
# Out:
# array(['0-17', '55+', '26-35', '46-50', '51-55', '36-45', '18-25'],
#       dtype=object)

# %%
def age_converter(age):
    if age == '55+':
        return 60
    else:
        return eval(age.replace('-','+'))/2

# %%
df['Age']=df['Age'].apply(age_converter)

# %%
df['Age'].value_counts()
# Out:
# 30.5    219587
# 40.5    110013
# 21.5     99660
# 48.0     45701
# 53.0     38501
# 60.0     21504
# 8.5      15102
# Name: Age, dtype: int64

# %%
df['Stay_In_Current_City_Years']=pd.to_numeric(df['Stay_In_Current_City_Years'],errors='coerce')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 550068 entries, 1000001 to 1006039
# Data columns (total 11 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   Product_ID                  550068 non-null  int64
#  1   Gender                      550068 non-null  object
#  2   Age                         550068 non-null  float64
#  3   Occupation                  550068 non-null  int64
#  4   City_Category               550068 non-null  object
#  5   Stay_In_Current_City_Years  550068 non-null  int64
#  6   Marital_Status              550068 non-null  int64
#  7   Product_Category_1          550068 non-null  int64
#  8   Product_Category_2          376430 non-null  float64
#  9   Product_Category_3          166821 non-null  float64
#  10  Purchase                    550068 non-null  int64
# dtypes: float64(3), int64(6), object(2)
# memory usage: 50.4+ MB

# %%
df.sample(18)
# Out:
#          Product_ID Gender   Age  Occupation City_Category  \
# User_ID
# 1000131      299242      M  21.5           4             C
# 1000934       26842      F  40.5           7             A
# 1000629      316842      F   8.5          10             C
# 1004422      257342      M  30.5           5             A
# 1001825      213742      M  30.5           7             C
# 1001650       64242      M  30.5          19             C
# 1004740       85842      F  30.5           3             C
# 1004155      127742      M  53.0          17             C
# 1001733      171342      M  21.5          14             B
# 1001354      317142      F  30.5           2             B
# 1001273      293742      M  40.5           2             C
# 1001399       71442      M  21.5          17             C
# 1001252      350342      M  60.0          13             C
# 1003051      280442      M  21.5          17             B
# 1000438      316642      M  21.5          11             A
# 1003562      288542      F  30.5           6             B
# 1004041      246742      M  21.5           3             B
# 1000151      211042      F  30.5          20             A
#
#          Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# User_ID
# 1000131                           4               0                   8
# 1000934                           0               0                   5
# 1000629                           2               0                   4
# 1004422                           1               1                   8
# 1001825                           4               1                   8
# 1001650                           1               0                   5
# 1004740                           3               0                  12
# 1004155                           1               0                   1
# 1001733                           0               1                  13
# 1001354                           3               0                   2
# 1001273                           3               1                   8
# 1001399                           1               0                  15
# 1001252                           3               0                   1
# 1003051                           0               0                  11
# 1000438                           3               0                   4
# 1003562                           4               0                   8
# 1004041                           2               0                  11
# 1000151                           1               1                   5
#
#          Product_Category_2  Product_Category_3  Purchase
# User_ID
# 1000131                 NaN                 NaN      7908
# 1000934                 NaN                 NaN      1749
# 1000629                 5.0                 NaN      2174
# 1004422                 NaN                 NaN      5839
# 1001825                 NaN                 NaN      9759
# 1001650                 NaN                 NaN      5397
# 1004740                 NaN                 NaN      1380
# 1004155                 2.0                15.0     15784
# 1001733                16.0                 NaN       564
# 1001354                15.0                 NaN      6776
# 1001273                 NaN                 NaN      8063
# 1001399                17.0                 NaN     21427
# 1001252                 6.0                 NaN      8165
# 1003051                 NaN                 NaN      4605
# 1000438                 5.0                 NaN      3474
# 1003562                 NaN                 NaN      7944
# 1004041                15.0                 NaN      5967
# 1000151                 NaN                 NaN      5205

# %% [markdown]
# # Handling missing Values

# %%
df[df['Product_ID']=='00050242']
# Out:
# Empty DataFrame
# Columns: [Product_ID, Gender, Age, Occupation, City_Category, Stay_In_Current_City_Years, Marital_Status, Product_Category_1, Product_Category_2, Product_Category_3, Purchase]
# Index: []

# %%
df[df['Product_Category_2'].isna()]['Product_ID']
# Out:
# User_ID
# 1000001     69042
# 1000001     87842
# 1000002    285442
# 1000005    274942
# 1000005     14542
#             ...
# 1006033    372445
# 1006035    375436
# 1006036    375436
# 1006038    375436
# 1006039    371644
# Name: Product_ID, Length: 173638, dtype: int64

# %% [markdown]
# ## Handle Product 2,3

# %%
pip install knnimpute
# Out:
# Requirement already satisfied: knnimpute in c:\users\ahmed\anaconda3\lib\site-packages (0.1.0)
# Requirement already satisfied: six in c:\users\ahmed\anaconda3\lib\site-packages (from knnimpute) (1.16.0)
# Requirement already satisfied: numpy>=1.10 in c:\users\ahmed\anaconda3\lib\site-packages (from knnimpute) (1.21.5)
# Note: you may need to restart the kernel to use updated packages.

# %%
IDS=1
#for ID in df['Product_ID'].unique():
    #df['Product_ID']=df['Product_ID'].replace(ID,IDS)
    #IDS += 1

# %%
df['Product_ID'].value_counts()
# Out:
# 265242    1880
# 25442     1615
# 110742    1612
# 112142    1562
# 57642     1470
#           ...
# 314842       1
# 298842       1
# 231642       1
# 204442       1
# 66342        1
# Name: Product_ID, Length: 3631, dtype: int64

# %%
#from sklearn.impute import KNNImputer
#imputer=KNNImputer(n_neighbors=1)

# %%
#nan_pro=['Product_Category_2', 'Product_Category_3']
#for col in nan_pro:
    #imputer.fit(df[['Product_ID',col]])
    #df[['Product_ID',col]]=imputer.fit_transform(df[['Product_ID',col]])

# %%
df['Product_Category_2'].fillna(0,inplace=True)
df['Product_Category_3'].fillna(0,inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 550068 entries, 1000001 to 1006039
# Data columns (total 11 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   Product_ID                  550068 non-null  int64
#  1   Gender                      550068 non-null  object
#  2   Age                         550068 non-null  float64
#  3   Occupation                  550068 non-null  int64
#  4   City_Category               550068 non-null  object
#  5   Stay_In_Current_City_Years  550068 non-null  int64
#  6   Marital_Status              550068 non-null  int64
#  7   Product_Category_1          550068 non-null  int64
#  8   Product_Category_2          550068 non-null  float64
#  9   Product_Category_3          550068 non-null  float64
#  10  Purchase                    550068 non-null  int64
# dtypes: float64(3), int64(6), object(2)
# memory usage: 50.4+ MB

# %%
df.sample(15)
# Out:
#          Product_ID Gender   Age  Occupation City_Category  \
# User_ID
# 1000166       72942      M  21.5           4             B
# 1001059       34342      F  30.5           0             B
# 1002211       57442      M  48.0           6             C
# 1001503      210042      M  30.5          12             A
# 1001941      254842      M  40.5          17             A
# 1000344      277642      M  40.5          14             C
# 1003387      270242      M  21.5           1             B
# 1004887       52842      M  21.5           2             B
# 1005371      289042      M  30.5          11             A
# 1004085      214442      F  30.5           6             A
# 1004521        1742      M  40.5          12             B
# 1001193      306042      M  30.5          12             C
# 1000877      255742      M  30.5           0             B
# 1001284      279442      M  48.0          16             A
# 1001879      171342      M  30.5           4             C
#
#          Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# User_ID
# 1000166                           1               1                   8
# 1001059                           3               0                   5
# 1002211                           2               1                   5
# 1001503                           2               0                   8
# 1001941                           1               0                   5
# 1000344                           1               1                   2
# 1003387                           3               1                   8
# 1004887                           1               1                  10
# 1005371                           0               0                   8
# 1004085                           1               0                   8
# 1004521                           1               0                   8
# 1001193                           3               1                   2
# 1000877                           1               1                   3
# 1001284                           1               1                  16
# 1001879                           1               1                  13
#
#          Product_Category_2  Product_Category_3  Purchase
# User_ID
# 1000166                 0.0                 0.0     10017
# 1001059                 0.0                 0.0      5405
# 1002211                14.0                16.0      7126
# 1001503                14.0                 0.0      6150
# 1001941                13.0                 0.0      5373
# 1000344                 3.0                10.0      6615
# 1003387                 0.0                 0.0      9867
# 1004887                15.0                 0.0     14316
# 1005371                 0.0                 0.0      7822
# 1004085                 0.0                 0.0      9905
# 1004521                14.0                 0.0      8089
# 1001193                 8.0                 0.0      9528
# 1000877                 4.0                 0.0     10766
# 1001284                 0.0                 0.0     12269
# 1001879                16.0                 0.0       747

# %% [markdown]
# # Feature Engineering

# %% [markdown]
# ## Handle City Category

# %%
C_C={'C':1,'B':2,'A':1}
df['City_Category']=df['City_Category'].map(C_C)

# %% [markdown]
# ## Handle Gender

# %%
Gen={'M':1,'F':2}
df['Gender']=df['Gender'].map(Gen)

# %%
df.sample(20)
# Out:
#          Product_ID  Gender   Age  Occupation  City_Category  \
# User_ID
# 1002453      144642       1  30.5           7              2
# 1001457       46242       1  30.5           1              2
# 1000157       71442       1  40.5          16              1
# 1004016      127242       1  53.0           0              2
# 1000149       32542       1  30.5           1              2
# 1002038      109542       2  48.0           1              2
# 1002380      135742       1  30.5           4              1
# 1001699      105642       2  30.5          19              1
# 1002127      370853       1  21.5           4              1
# 1004482      128242       2  40.5           1              1
# 1002012      304542       1  30.5           4              2
# 1000960      113042       1   8.5          10              1
# 1000991      266642       2  30.5           9              1
# 1005013      323742       1  21.5           4              1
# 1004834      120342       2  48.0           9              1
# 1003110      227542       1  30.5           0              2
# 1001608      265242       1  30.5          11              2
# 1002760       84842       1  60.0           0              1
# 1003942      151742       1  21.5           4              2
# 1001752      216342       1  30.5           3              2
#
#          Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# User_ID
# 1002453                           0               0                   1
# 1001457                           1               1                   8
# 1000157                           1               0                  15
# 1004016                           1               0                   1
# 1000149                           2               1                   8
# 1002038                           3               1                   8
# 1002380                           0               1                   6
# 1001699                           0               0                   8
# 1002127                           0               1                  19
# 1004482                           1               0                   5
# 1002012                           3               1                   1
# 1000960                           4               0                  11
# 1000991                           3               1                   1
# 1005013                           4               0                   8
# 1004834                           1               1                   5
# 1003110                           3               1                  13
# 1001608                           1               1                   5
# 1002760                           1               0                   8
# 1003942                           4               0                   8
# 1001752                           1               0                   3
#
#          Product_Category_2  Product_Category_3  Purchase
# User_ID
# 1002453                15.0                16.0     11922
# 1001457                 0.0                 0.0      9998
# 1000157                17.0                 0.0     21186
# 1004016                16.0                 0.0     11688
# 1000149                 0.0                 0.0      3885
# 1002038                14.0                17.0      7943
# 1002380                 8.0                 0.0     12134
# 1001699                 0.0                 0.0      8124
# 1002127                 0.0                 0.0        37
# 1004482                12.0                14.0      6904
# 1002012                 5.0                 0.0      4363
# 1000960                16.0                 0.0      7488
# 1000991                 8.0                 9.0     12113
# 1005013                 0.0                 0.0      7826
# 1004834                17.0                 0.0      8735
# 1003110                 0.0                 0.0       758
# 1001608                 8.0                 0.0      3597
# 1002760                16.0                 0.0      7799
# 1003942                15.0                16.0      5989
# 1001752                 4.0                 5.0     13654

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 550068 entries, 1000001 to 1006039
# Data columns (total 11 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   Product_ID                  550068 non-null  int64
#  1   Gender                      550068 non-null  int64
#  2   Age                         550068 non-null  float64
#  3   Occupation                  550068 non-null  int64
#  4   City_Category               550068 non-null  int64
#  5   Stay_In_Current_City_Years  550068 non-null  int64
#  6   Marital_Status              550068 non-null  int64
#  7   Product_Category_1          550068 non-null  int64
#  8   Product_Category_2          550068 non-null  float64
#  9   Product_Category_3          550068 non-null  float64
#  10  Purchase                    550068 non-null  int64
# dtypes: float64(3), int64(8)
# memory usage: 50.4 MB

# %%
## split it into x--> data,  y--> target
X = df.drop('Purchase', axis =1)
y = df['Purchase']

# %%
## Models 
models = [
    ('Linear Regression', LinearRegression()), 
    ('DTR', DecisionTreeRegressor()), 
    ('RFR', RandomForestRegressor()), 
    ('ADA', AdaBoostRegressor()), 
    ('GBR', GradientBoostingRegressor()), 
    ('XGBR', XGBRegressor())
]

# %%
# Define the numerical column
numerical_cols = X.select_dtypes(include='number').columns


# Initialize RFE feature selector
RFE_selector = RFE(XGBRegressor(), n_features_to_select=6) 

# Create the ColumnTransformer
preprocessor = ColumnTransformer(transformers=[('num', RobustScaler(), numerical_cols), 
                                              ],remainder='passthrough')


for model_name, model in models:
    # Print model name
    print(f"For {model_name}:")

    # Steps Creation
    steps = list()
    steps.append(('preprocessor', preprocessor))

    # Choose the feature selector based on your preference
    steps.append(('feature_selector', RFE_selector))  # RFE feature selection
    
    steps.append((model_name, model))

    # Create the pipeline
    pipeline = Pipeline(steps=steps)

    ## Scoring
    # Perform cross-validation
    # Example evaluation metrics
    cv_results = cross_validate(pipeline, X, y, scoring='r2', cv=5, return_train_score=True)  # X and y are your input data and targets



    # Access the results
    print("test :", cv_results['test_score'].mean())
    print("train:", cv_results['train_score'].mean())
    print('*' * 50)
# Out:
# For Linear Regression:
# test : 0.1497402087021043
# train: 0.15247339230024112
# **************************************************
# For DTR:
# test : 0.6829282204185866
# train: 0.7585531363204305
# **************************************************
# For RFR:
# test : 0.6974521515877096
# train: 0.7562397617139697
# **************************************************
# For ADA:
# test : 0.4294075160363732
# train: 0.4432304448949843
# **************************************************
# For GBR:
# test : 0.6585020529312718
# train: 0.6617020377036302
# **************************************************
# For XGBR:
# test : 0.7099445614802885
# train: 0.7178330924357222
# **************************************************

# %%
# define the parameter grid
param_grid = {
    'XGBR__max_depth': [2, 4, 6],
    'XGBR__learning_rate': [0.1, 0.01],
    'XGBR__n_estimators': [50, 100, 200]
}

# %%
steps=[]
steps.append(('preprocessor', preprocessor))
steps.append(('feature_selector', RFE_selector))
steps.append(('XGBR',XGBRegressor()))
pipeline=Pipeline(steps=steps)

# %%
# Create GridSearchCV instance
grid_search = GridSearchCV(estimator=pipeline, param_grid=param_grid, cv=5, scoring='r2', n_jobs=-1, return_train_score=True)

# Fit the pipeline with GridSearch to the data
grid_search.fit(X, y)

# Get the best parameters and best score
best_params = grid_search.best_params_
best_score = grid_search.best_score_

print("Best Parameters:", best_params)
print("Best Score:", best_score)
# Out:
# Best Parameters: {'XGBR__learning_rate': 0.1, 'XGBR__max_depth': 6, 'XGBR__n_estimators': 200}
# Best Score: 0.7045915671415646

# %%
# Get the mean test score and mean train score for the best estimator
mean_test_score = grid_search.cv_results_['mean_test_score'][grid_search.best_index_]
mean_train_score = grid_search.cv_results_['mean_train_score'][grid_search.best_index_]

print("Mean Test Score:", mean_test_score)
print("Mean Train Score:", mean_train_score)
# Out:
# Mean Test Score: 0.7045915671415646
# Mean Train Score: 0.7110016501890843

# %%
final_model=grid_search.best_estimator_
final_model
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('num', RobustScaler(),
#                                                   Index(['Product_ID', 'Gender', 'Age', 'Occupation', 'City_Category',
#        'Stay_In_Current_City_Years', 'Marital_Status', 'Product_Category_1',
#        'Product_Category_2', 'Product_Category_3'],
#       dtype='object'))])),
#                 ('feature_selector',
#                  RFE(estimator=XGBRegressor...
#                               feature_types=None, gamma=None, gpu_id=None,
#                               grow_policy=None, importance_type=None,
#                               interaction_constraints=None, learning_rate=0.1,
#                               max_bin=None, max_cat_threshold=None,
#                               max_cat_to_onehot=None, max_delta_step=None,
#                               max_depth=6, max_leaves=None,
#                               min_child_weight=None, missing=nan,
#                               monotone_constraints=None, n_estimators=200,
#                               n_jobs=None, num_parallel_tree=None,
#                               predictor=None, random_state=None, ...))])
